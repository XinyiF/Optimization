# %% [markdown]
# # Homework \#5
# Due July 29 @ 11:59pm
#
# ## Submission requirements
# Upload a **single PDF file** of your IJulia notebook for this entire assigment. Clearly denote which question each section of your PDF corresponds to.

# %% [markdown]
# ## Problem 1 -- Nonconvex Quadratics
#
# Suppose you have the constraint:
#
# $2x^2 + y^2+ 2z^2 - 3xy + xz - 4yz \leq 0 \quad\quad$ (1)

# %% [markdown]
# (a)  Write constraint (1) in the standard form $v^TQv\leq 0$ where $Q$ is a symmetric matrix.  What is $Q$ and what is $v$?
#
# $Q=\left[ \begin{array}{ccc} 2 & -\frac{3}{2} &  \frac{1}{2} \\  -\frac{3}{2} & 1 & -2\\ \frac{1}{2} & -2 & 2 \end{array} \right]$ $v=\left[ \begin{array}{ccc} x \\y \\z \end{array} \right]$
#
# $\left[ \begin{array}{ccc} x \\y \\z \end{array} \right]^\mathrm T\left[ \begin{array}{ccc} 2 & -\frac{3}{2} &  \frac{1}{2} \\  -\frac{3}{2} & 1 & -2\\ \frac{1}{2} & -2 & 2 \end{array} \right]\left[ \begin{array}{ccc} x \\y \\z \end{array} \right]\leq 0$

# %% [markdown]
# (b)  This constraint is not convex (i.e., the set of points satisfying the constraint is not an ellipsoid). Explain why this is the case. *Hint*: You can perform an orthogonal decomposition of a symmetric matrix $Q$ in Julia like this:
#
# If the function $f$ is convex, then $f(x+y)\leq f(x)+f(y)$, so I try some cases as below:

# %%
using LinearAlgebra
Q=[  2  -3/2  1/2
    -3/2 1   -2
     1/2   -2  2]
(L,U) = (eigvals(Q),eigvecs(Q)) # L is the vector of eigenvalues and U is orthogonal
Q_new=U * Diagonal(L) * U' # this is equal to Q (as long as Q was symmetric to begin with)
;

x=[-1
-3
22]
y=[10
4
3]
xy=x+y
sum1=x'*Q*x+y'*Q*y
sum2=xy'*Q*xy
if sum1>=sum2
    println("This is a convex constraint")
else
    println("This isn't a convex constraint")
end
# Out:
# This isn't a convex constraint

# %% [markdown]
# (c)  We can write constraint (1) in norm format as follows:
#
# $‖Av‖_2^2−‖Bv‖_2^2\leq 0 \quad\quad$ (2)
#
# Find matrices $A$ and $B$ that make this constraint equivalent to (1).
#
# $‖Av‖_2^2−‖Bv‖_2^2=v^TA^TAv-v^TB^TBv$\
# $v^TQv=v^TULU^Tv$
#
# Suppose $L=diag(\lambda_1,\lambda_2,\lambda_3)=diag(\lambda_{11},\lambda_{12},\lambda_{13})-diag(\lambda_{21},\lambda_{22},\lambda_{23})$
#
# Suppose $\Lambda_1=diag(\sqrt{\lambda_{11}},\sqrt{\lambda_{12}},\sqrt{\lambda_{13}})$\
# $\Lambda_2=diag(\sqrt{\lambda_{21}},\sqrt{\lambda_{22}},\sqrt{\lambda_{23}})$
#
# Then $L=L_1-L_2$:
# $v^TQv=v^TU(L_1-L_2)U^Tv$
#
# $=v^TUL_1U^Tv-v^TUL_2U^Tv$
#
# $=v^TU\Lambda_1UU^T\Lambda_1U^Tv-v^TU\Lambda_2UU^T\Lambda_2U^Tv$
#
# $=‖Av‖_2^2−‖Bv‖_2^2$
#
# $A=U^T\Lambda_1U, B=U^T\Lambda_2U$
#
# So assume that $L_1=diag(5,5,5)$, then $L_2=(5.87016 ,3.48151 ,0.648334)$

# %%
L1= Diagonal([5 
        5 
        5])
Lam2=(L1-Diagonal(L))^0.5
Lam1=L1^0.5
display(U'*Lam1*U)
display(U'*Lam2*U)
# Out:
# 3×3 Array{Float64,2}:
#   2.23607       0.0           6.66134e-16
#  -1.11022e-16   2.23607      -1.11022e-16
#   4.44089e-16  -1.11022e-16   2.23607
# 3×3 Array{Float64,2}:
#  1.66183    0.468433   0.232715
#  0.468433   1.82385   -0.623823
#  0.232715  -0.623823   1.60824

# %% [markdown]
# Then $A=\left[ \begin{array}{ccc} 2.23607&0.0&6.66134e-16 \\ -1.11022e-16&2.23607&-1.11022e-16\\ 4.44089e-16&  -1.11022e-16&2.23607 \end{array} \right]$
#
# $B=\left[ \begin{array}{ccc} 1.66183& 0.468433&0.232715\\0.468433&1.82385&-0.623823\\ 0.232715& -0.623823&1.60824  \end{array} \right]$

# %% [markdown]
# (d)  Explain how to find $(x, y, z)$ that satisfy the above constraint but make $2x^2+ y^2 + 2z^2$ arbitrarily large.
#
# $2x^2+ y^2 + 2z^2=\left[ \begin{array}{ccc} x \\y \\z \end{array} \right]^\mathrm T\left[ \begin{array}{ccc} 2 & 0 &  0\\ 0& 1 & 0\\ 0& 0 & 2 \end{array} \right]\left[ \begin{array}{ccc} x \\y \\z \end{array} \right]$

# %%
using JuMP,Ipopt
m = Model(Ipopt.Optimizer)
set_optimizer_attribute(m,"print_level",0)
@variable(m, x)
@variable(m, y)
@variable(m, z)

@objective(m, Max, 2*x^2+y^2+2*z^2)

@constraint(m, 2*x^2+y^2+2*z^2-3*x*y+x*z-4*y*z<=0)

optimize!(m)

println(value(x))
println(value(y))
println(value(z))
# Out:
# 0.0
# 0.0
# 0.0

# %% [markdown]
# ## Problem 2 -- Circles within Circles
#
# Formulate a convex program to solve the minimum enclosing ball (MEB) problem.  You need to determine the center \$z\$ of a ball, and its radius \$d\$ so that each of the circles centered at \$c_i\$ with radius \$r_i\$ are enclosed in your generated circle.  Your task is to find the cirle of smallest radius that encircles all the other circles.
#
# You can use the following code to start building your model. Start with $n=5$ circles to help with debugging, but display the output of your model for both $n=5$ and a very large value of $n$, such as $n=200$.

# %%
n = 200
using Random, PyPlot
r = [rand()*0.2 for i in 1:n] # randomly generate n radii with length between 0 and 0.2

# randomly generate n points with (x,y) coords between 0 and 1
c = [rand() for i in 1:n, j in 1:2] 

for i in 1:n
    # plot circle radius r[i] with center (x[i],y[i])
    plot( c[i,1] .+ r[i]*cos.(t), c[i,2] .+ r[i]*sin.(t)) 
end
axis("equal"); # make x and y scales equal
# Out:
# Figure(PyObject <Figure size 640x480 with 1 Axes>)

# %%
using Random, PyPlot, JuMP, Ipopt
m = Model(Ipopt.Optimizer)
set_optimizer_attribute(m,"print_level",0)
@variable(m, x >= 0)
@variable(m, y >= 0)
@variable(m, R >= 0)

@objective(m, Min, R)

@NLconstraint(m, distance[t in 1:n],(c[t,1]-x)^2+(c[t,2]-y)^2<=(R-r[t])^2)
@constraint(m, Rr[t in 1:n],R>=r[t])

optimize!(m)
display(value(x))
display(value(y))
display(value(R))
x=value(x)
y=value(y)
R=value(R)
# for each of the n points
t = range(0,stop=2*pi,length=100) # parameter that traverses the circle

# for each of the n points
for i in 1:n
    # plot circle radius r[i] with center (x[i],y[i])
    plot( c[i,1] .+ r[i]*cos.(t), c[i,2] .+ r[i]*sin.(t)) 
end
plot(x .+ R*cos.(t), y .+ R*sin.(t))
axis("equal"); # make x and y scales equal
# Out:
# 0.5459701146940559
# 0.4024285265350231
# 0.7800772363998696
# Figure(PyObject <Figure size 640x480 with 1 Axes>)
