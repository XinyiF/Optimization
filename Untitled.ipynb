# %% [markdown]
# ## Standard Form
#
# $\max c^Tx+d$\
# $s.t. Ax \leq b$\
# $x \geq 0$

# %% [markdown]
# ## For Possible Cases For LP Problems
#
# The LP is feasible and has an optimal solution.(The single solution lies at the extreme point)
#
# <img src="oneSol.png" style="zoom:40%" />
